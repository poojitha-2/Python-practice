# %% [markdown]
# ### VARIABLES

# %%
age = 23
print(age)
# Out:
# 23

# %%
x = 10
print(x)
x = 20
print(x)
# Out:
# 10
# 20

# %%
name = 'Poojitha'
print(f"Hello, {name}")
# Out:
# Hello, Poojitha

# %%
a= 5
b= a
a= 10
print(b)
# Out:
# 5

# %%
a = 5
b= 10
a = a + b
b = a - b
a = a - b
print(f"a = {a}")
print(f"b = {b}")
# Out:
# a = 10
# b = 5

# %%
x=5;y=10;z=9
print(x)
print(y)
print(z)
# Out:
# 5
# 10
# 9

# %%
print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8796/302864193.py in <module>
# ----> 1 print(num)
#
# NameError: name 'num' is not defined

# %%
x = 5
x = x+3
x = x*2
print(x)
# Out:
# 16

# %% [markdown]
# ### DATA TYPES

# %%
a = 10
b = 3.14
c = "Python"
d = True
e = None
print(a,type(a))
print(b,type(b))
print(c,type(c))
print(d,type(d))
print(e,type(e))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Python <class 'str'>
# True <class 'bool'>
# None <class 'NoneType'>

# %%
num = 5
floatnum = float(num)
print(type(floatnum))
# Out:
# <class 'float'>

# %%
string = str(num)
print(type(string))
# Out:
# <class 'str'>

# %%
x = "10"
y = 5
print(x*y)
# Out:
# 1010101010

# %%
print("Age: "+25)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8796/46311567.py in <module>
# ----> 1 print("Age: "+25)
#
# TypeError: can only concatenate str (not "int") to str

# %%
a = 10
b = 10.0 
print(a == b)
print(type(a) == type(b))
# Out:
# True
# False

# %% [markdown]
# ### OPERATORS

# %%
#Arithmetic Operators
x = 10
y = 5
print(f"sum = {x+y}")
print(f"Difference = {x-y}")
print(f"product = {x*y}")
print(f"quotient = {x/y}")
print(f"{x//y}")
print(f"Remainder = {x%y}")
# Out:
# sum = 15
# Difference = 5
# product = 50
# quotient = 2.0
# 2
# Remainder = 0

# %%
print(10/3)
print(10//3)
print(10%3)
# Out:
# 3.3333333333333335
# 3
# 1

# %%
#Relational operators & logical Operators
print(5 > 3 and 2 < 1)
# Out:
# False

# %%
x = 12
if x > 0:
    print("Positive")
elif x < 0:
    print("Negative")
elif x == 0:
    print(zero)
# Out:
# Positive

# %%
x = 5
print(x > 3 or x <2)
# Out:
# True

# %%
#Assignment Operators
x = 10
x += 5
x *= 2
print(x)
# Out:
# 30

# %%
num1 = int(input("Enter number:"))
num2 = int(input("Enter number"))
print(num1 + num2)
print(type(num1+num2))
# Out:
# Enter number:21
# Enter number42
# 63
# <class 'int'>

# %%
num = 32
if num%2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Even

# %%
a = 3
b = 4
print(a+b*2)
# Out:
# 11
